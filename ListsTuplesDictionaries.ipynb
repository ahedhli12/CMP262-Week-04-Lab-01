# %% [markdown]
# # CMP 262 – Week 4, Lab 1
# ## Working with Lists, Tuples, and Dictionaries
#
# ### Scenario
# You are helping organize simple student performance data for a small academic program. You will use Python collections to store, review, update, and summarize the data.
#
# By the end of this lab, you should be able to decide when a **list**, **tuple**, or **dictionary** is the best structure to use.

# %% [markdown]
# ## Part 1 – Lists: Working with Exam Scores
#
# A student has the following exam scores:
#
# `78, 84, 91, 87, 95, 82`
#
# Create a list named `exam_scores` containing these values. Then display the complete list.

# %%
# Write your code here

# %% [markdown]
# ### Task 1 – Accessing List Values
# Display:
# - the first score
# - the last score
# - the number of scores in the list

# %%
# Write your code here

# %% [markdown]
# ### Task 2 – Basic Analysis
# Use Python functions to calculate and display:
# - highest score
# - lowest score
# - total of all scores
# - average score
#
# Do not calculate the values manually.

# %%
# Write your code here

# %% [markdown]
# ### Task 3 – Updating the List
# The second score was entered incorrectly. Change it from `84` to `86`.
#
# Then add a new score of `90` to the end of the list.
#
# Display the updated list.

# %%
# Write your code here

# %% [markdown]
# ## Part 2 – List Challenges
#
# Use the updated `exam_scores` list.

# %% [markdown]
# ### Challenge 1 – Scores Above the Average
# Calculate the average score.
#
# Use a loop to display only the scores that are greater than the average.
#
# Do not manually type the qualifying scores.

# %%
# Write your code here

# %% [markdown]
# ### Challenge 2 – Count High Scores
# Use a loop to count how many scores are `90` or higher.
#
# Display the result in a message such as:
#
# `Number of scores 90 or higher: 3`

# %%
# Write your code here

# %% [markdown]
# ### Challenge 3 – Find the First High Score
# Use a loop to find the **index of the first score that is 90 or higher**.
#
# Display both the score and its index.
#
# Do not sort the list. The goal is to work with the original order.

# %%
# Write your code here

# %% [markdown]
# ## Part 3 – Tuples: Fixed Student Information
#
# Some student information should normally remain fixed during the program.
#
# Create a tuple named `student_info` containing:
#
# `("Jordan", "DS101", "Data Science")`
#
# The values represent the student's name, student program code, and major.

# %%
# Write your code here

# %% [markdown]
# ### Task 4 – Access Tuple Values
# Display each value from `student_info` using its index.

# %%
# Write your code here

# %% [markdown]
# ### Task 5 – Tuple Unpacking
# Unpack `student_info` into three variables:
# - `name`
# - `program_code`
# - `major`
#
# Display the three variables.

# %%
# Write your code here

# %% [markdown]
# ### Challenge 4 – Changing Tuple Data
# Suppose the student's major changes from `Data Science` to `Computer Science`.
#
# Because tuples are immutable, you cannot directly change one item.
#
# Convert the tuple to a list, update the major, and convert it back to a tuple.
#
# Display the final tuple.

# %%
# Write your code here

# %% [markdown]
# ### Think About It
# In 2–3 sentences, explain why a tuple could be useful for data that should not normally change.

# %% [markdown]
# Write your answer here.

# %% [markdown]
# ## Part 4 – Dictionaries: Creating a Student Record
#
# Create a dictionary named `student_record` with these key-value pairs:
#
# - `name`: `Jordan`
# - `major`: `Computer Science`
# - `course`: `CMP262`
# - `grade`: `91`
#
# Display the dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Task 6 – Access Dictionary Values
# Display only the student's:
# - name
# - course
# - grade
#
# Access each value using its key.

# %%
# Write your code here

# %% [markdown]
# ### Task 7 – Update and Add Information
# Change the student's grade from `91` to `94`.
#
# Then add a new key named `credits` with a value of `3`.
#
# Display the updated dictionary.

# %%
# Write your code here

# %% [markdown]
# ### Task 8 – Loop Through a Dictionary
# Use a loop to display every key and value in `student_record`.
#
# Example output format:
#
# `name : Jordan`

# %%
# Write your code here

# %% [markdown]
# ## Part 5 – Combined Data Challenge
#
# Now you will combine lists and dictionaries.
#
# Create the following dictionary:
#
# ```python
# course_scores = {
#     "CMP262": [88, 92, 95],
#     "CMP129": [84, 90, 87],
#     "MAT123": [91, 89, 94]
# }
# ```

# %%
# Create course_scores here

# %% [markdown]
# ### Final Challenge
# Using `course_scores`:
#
# 1. Loop through every course.
# 2. Calculate the average score for each course.
# 3. Display the course name and average.
# 4. Keep track of the course with the highest average.
# 5. After the loop finishes, display the course with the highest average.
# 6. Also display how many total individual scores are stored across all courses.
#
# Do not manually calculate or type the averages.

# %%
# Write your code here

# %% [markdown]
# ## Part 6 – Choosing the Correct Data Structure
#
# For each situation below, write **list**, **tuple**, or **dictionary**, and briefly explain why.
#
# 1. A collection of daily temperatures that will be updated.
# 2. A student's fixed birth date represented as month, day, and year.
# 3. A student record containing a name, major, GPA, and email.

# %% [markdown]
# Write your answers here.

# %% [markdown]
# ## Reflection
#
# In 3–5 sentences, explain the main difference between lists, tuples, and dictionaries. Which one do you think will be most useful when working with datasets later in this course, and why?

# %% [markdown]
# Write your answer here.
