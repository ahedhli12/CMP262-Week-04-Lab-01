# %% [markdown]
# # CMP 262 – Week 4, Lab 1\n## Lists, Tuples, and Dictionaries\n\nIn this lab, you will review lists and tuples and then practice using dictionaries.\n\nComplete each section in order. Run every code cell and check your results before continuing.

# %% [markdown]
# ## Part 1 – List Review\n\nCreate a list named `temperatures` containing the following values:\n\n`72, 68, 75, 81, 77, 69, 74`\n\nThen display the complete list.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 1\nDisplay:\n- the first temperature\n- the last temperature\n- the number of temperatures in the list

# %%
# Write your code here\n

# %% [markdown]
# ### Question 2\nUse Python functions to display:\n- the highest temperature\n- the lowest temperature\n- the total of all temperatures\n- the average temperature\n\nFor the average, calculate it using the list values rather than typing the answer directly.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 3 – List Update\nThe fourth temperature was entered incorrectly. Change it from `81` to `79`.\n\nThen add a new temperature of `73` to the end of the list and display the updated list.

# %%
# Write your code here\n

# %% [markdown]
# ## Part 2 – List Challenge\n\nUse the updated `temperatures` list for the next questions.

# %% [markdown]
# ### Challenge 1 – Above Average\nCalculate the average temperature. Then use a loop to display only the temperatures that are greater than the average.\n\nDo not manually type the temperatures.

# %%
# Write your code here\n

# %% [markdown]
# ### Challenge 2 – Count Values\nUse a loop to count how many temperatures are `75` or higher.\n\nDisplay a message similar to:\n\n`Number of temperatures 75 or higher: 4`\n\nYour result should be calculated from the list.

# %%
# Write your code here\n

# %% [markdown]
# ### Challenge 3 – Slicing\nCreate a new list named `middle_temperatures` containing all values except the first and last values.\n\nUse list slicing. Display the new list.

# %%
# Write your code here\n

# %% [markdown]
# ## Part 3 – Tuples\n\nCreate a tuple named `student` containing:\n\n`\"Jordan\", \"CMP262\", 92`\n\nThe values represent the student's name, course, and grade.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 4\nDisplay each value from the tuple using its index.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 5 – Tuple Unpacking\nUnpack the `student` tuple into three variables named:\n- `name`\n- `course`\n- `grade`\n\nDisplay the three variables.

# %%
# Write your code here\n

# %% [markdown]
# ### Tuple Challenge\nSuppose the student's grade needs to change from `92` to `95`.\n\nBecause tuples are immutable, you cannot directly replace the value.\n\nConvert the tuple to a list, update the grade, and convert it back to a tuple. Display the final tuple.

# %%
# Write your code here\n

# %% [markdown]
# ### Think About It\nIn the Markdown cell below, explain in 2–3 sentences why a tuple might be preferred over a list when data should not normally change.

# %% [markdown]
# Write your answer here.

# %% [markdown]
# ## Part 4 – Dictionaries\n\nCreate a dictionary named `student_record` with the following key-value pairs:\n\n- `name`: `Jordan`\n- `course`: `CMP262`\n- `grade`: `95`\n- `major`: `Data Science`\n\nDisplay the dictionary.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 6\nDisplay only the student's name and grade by accessing the dictionary using the appropriate keys.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 7 – Update and Add Data\nChange the student's grade to `97`.\n\nThen add a new key named `credits` with a value of `3`.\n\nDisplay the updated dictionary.

# %%
# Write your code here\n

# %% [markdown]
# ### Question 8 – Loop Through a Dictionary\nUse a loop to display every key and value in `student_record`.\n\nExample format:\n\n`name : Jordan`

# %%
# Write your code here\n

# %% [markdown]
# ## Part 5 – Final Challenge\n\nThe following dictionary stores course names as keys and a list of three exam grades as the value for each course:\n\n```python\ncourse_grades = {\n    \"CMP262\": [88, 92, 95],\n    \"CMP129\": [84, 90, 87],\n    \"MAT123\": [91, 89, 94]\n}\n```\n\nCopy the dictionary into the code cell below.

# %%
# Create course_grades here\n

# %% [markdown]
# ### Final Challenge Tasks\nUsing `course_grades`:\n\n1. Loop through each course.\n2. Calculate the average grade for each course.\n3. Display the course name and its average.\n4. Keep track of the course with the highest average.\n5. After the loop finishes, display the course with the highest average.\n\nDo not manually calculate or type the averages.

# %%
# Write your code here\n

# %% [markdown]
# ## Reflection\n\nAnswer the following in 2–4 sentences:\n\nWhat is one important difference between a list, tuple, and dictionary? Give one situation where each could be useful.

# %% [markdown]
# Write your answer here.
